# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data=[6,7,8,9,0]
series=pd.Series(data)
print("series\n", series)
# Out:
# series
#  0    6
# 1    7
# 2    8
# 3    9
# 4    0
# dtype: int64

# %%
data=[1,2,3,4]
index = ['a','b','c','d']
pd.Series(data,index=index)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
# dataframe
# create a dataframe from a dictionry oof list

data = {
    'Name':['krish','jack','john'],
    'Age':[20,30,40],
    'City':['delhi','gurugram','kurukshetra']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age         City
# 0  krish   20        delhi
# 1   jack   30     gurugram
# 2   john   40  kurukshetra
# <class 'pandas.core.frame.DataFrame'>

# %%
data = [
    {'Name':'aakash', 'Age':20,'city':'kurukshetra'},
    {'Name':'aakash', 'Age':20,'city':'kurukshetra'},
    {'Name':'aakash', 'Age':20,'city':'kurukshetra'},
    {'Name':'aakash', 'Age':20,'city':'kurukshetra'},
    {'Name':'aakash', 'Age':20,'city':'kurukshetra'},
]
df=pd.DataFrame(data)
print(df)
# Out:
#      Name  Age         city
# 0  aakash   20  kurukshetra
# 1  aakash   20  kurukshetra
# 2  aakash   20  kurukshetra
# 3  aakash   20  kurukshetra
# 4  aakash   20  kurukshetra

# %%
df['Name']
# Out:
# 0    aakash
# 1    aakash
# 2    aakash
# 3    aakash
# 4    aakash
# Name: Name, dtype: object

# %%
df.loc[0]
# Out:
# Name         aakash
# Age              20
# city    kurukshetra
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name         aakash
# Age              20
# city    kurukshetra
# Name: 0, dtype: object

# %%
df.iloc[0][0]
# Out:
# C:\Users\talya\AppData\Local\Temp\ipykernel_1412\2900375399.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0]
# 'aakash'

# %%
df
# Out:
#      Name  Age         city
# 0  aakash   20  kurukshetra
# 1  aakash   20  kurukshetra
# 2  aakash   20  kurukshetra
# 3  aakash   20  kurukshetra
# 4  aakash   20  kurukshetra

# %%
#accessing a specified element
df.at[2,'Age']
# Out:
# np.int64(20)

# %%
df.iat[2,2]
# Out:
# 'kurukshetra'

# %%
#adding a coloum
df['Salary']=[2,3,4,5,6]
df
# Out:
#      Name  Age         city  Salary
# 0  aakash   20  kurukshetra       2
# 1  aakash   20  kurukshetra       3
# 2  aakash   20  kurukshetra       4
# 3  aakash   20  kurukshetra       5
# 4  aakash   20  kurukshetra       6

# %%
df.drop('Salary',axis=1,inplace=True)

# %%
df
# Out:
#      Name  Age         city
# 0  aakash   20  kurukshetra
# 1  aakash   20  kurukshetra
# 2  aakash   20  kurukshetra
# 3  aakash   20  kurukshetra
# 4  aakash   20  kurukshetra

# %%
df['Age']+1
# Out:
# 0    21
# 1    21
# 2    21
# 3    21
# 4    21
# Name: Age, dtype: int64

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#      Name  Age         city
# 1  aakash   20  kurukshetra
# 2  aakash   20  kurukshetra
# 3  aakash   20  kurukshetra
# 4  aakash   20  kurukshetra
